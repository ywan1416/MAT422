# %% [markdown]
# <a href="https://colab.research.google.com/github/ywan1416/MAT422/blob/main/HW3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %% [markdown]
# # 3.3.1. Necessary and sufficient conditions of local minimizers

# %% [markdown]
# Global Minimizer: If 𝑥 *is a point where f (𝑥 *)≤f(x) for all x∈R, then 𝑥 * is the global minimizer.

# %% [markdown]
# Local Minimizer: If 𝑥 * is a point such that there exists a small neighborhood around 𝑥 * where f(𝑥 *)≤f(x) for all
# 𝑥 in that neighborhood, then 𝑥 * is a local minimizer.

# %% [markdown]
# Descent Direction: If there exists a vector 𝑣 such that it is aligned with the direction of the derivative and ∇𝑓(𝑥)𝑇𝑣 < 0, then 𝑣 is a descent direction for 𝑓 at 𝑥.

# %% [markdown]
# 3.3.1.1 Suﬀicient conditions for Local Minimizers

# %% [markdown]
# First-Order Necessary Condition:  If 𝑥0  is a local minimizer (not necessarily global), then the gradient at that point must be zero.

# %% [markdown]
# Second-Order Necessary Condition: If 𝑥0 is a local minimizer, then the Hessian matrix 𝐻𝑓(𝑥0) must be positive semi-definite (PSD).

# %%
#define a function f(x,y)
def objective(vars):
    x, y = vars
    return x - 2 * y

#define the initial guess
initial_guess = [0.5, 0.5]

#calculate the minimize
min = minimize(objective, initial_guess)

print(f"Solution (x*, y*): {min.x}")
print(f"Minimum value of f(x*, y*): {min.fun}")
# Out:
# Solution (x*, y*): [-2.76311825e+10  5.52623581e+10]
# Minimum value of f(x*, y*): -138155898762.21378

# %% [markdown]
# # 3.3.2. Convexity and global minimizers

# %% [markdown]
# 3.3.2.1 Convex Sets and Functions

# %% [markdown]
# A convex function has a “bowl shape” meaning that the function curves upwards. For convex functions, any local minimizer is also a global minimizer.

# %% [markdown]
# 3.3.2.2 Global Minimizers of Convex Functions

# %% [markdown]
# For a convex function, the local minimizer is always the global minimizer, and at this point, the gradient or first derivative equals zero

# %%
# Define the convex function
def f(x):
    return x**2+x
x_values = np.linspace(-5, 5, 100)
y_values = f(x_values)

# Plot the function
plt.figure(figsize=(8,6))
plt.plot(x_values, y_values, label="f(x) = x^2+x")
plt.scatter(-1/2, f(-1/2), color='red', label="Global Minimizer (x=-1/2, f(x)=-1/4)")
plt.title("Convex Function: f(x) = x^2+x")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 3.3.3. Gradient descent

# %% [markdown]
# A strongly convex function curves upwards and has a steeper curvature than a regular convex function. This property ensures that the function has only one minimum, which is both a local and global minimizer.

# %% [markdown]
# 3.3.3.1 Steepest Descent

# %%
# Define the strongly convex function
def f(x):
    return x**2 + 2*x + 1
x_values = np.linspace(-4, 2, 100)
y_values = f(x_values)

# Plot the function
plt.figure(figsize=(8,6))
plt.plot(x_values, y_values, label="f(x) = x^2 + 2x + 2")
plt.scatter(-1, f(-1), color='red', label="Global Minimizer (x=-1, f(x)=1)")
plt.title("Strongly Convex Function: f(x) = x^2 + 2x + 2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.legend()
plt.grid(True)
plt.show()
